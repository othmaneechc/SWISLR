# %% [markdown]
# #### Install Dependencies!

# %%
# !pip install pdfminer
# !pip install tqdm
# !pip install python-time
# !pip install nltk

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.pdfpage import PDFPage
from pdfminer.layout import LAParams
from tqdm import tqdm
from io import StringIO

import json
from collections import Counter
import concurrent.futures
from multiprocessing import Pool
from functools import partial

import nltk
import spacy
import numpy as np
import glob
import pandas as pd

# %% [markdown]
# #### Boilerplat Function!

# %%
def get_pdf_file_content(path_to_pdf):
    # Set parameters 
    out_text = StringIO()
    text_converter = TextConverter(PDFResourceManager(caching=True), out_text, laparams=LAParams())
    interpreter = PDFPageInterpreter(PDFResourceManager(caching=True), text_converter)

    fp = open(path_to_pdf, 'rb')

    # Set the maximum number of pages to read
    max_pages = 7

    # Use tqdm to create a progress bar
    # with tqdm(total=max_pages, desc="Extracting") as pbar:
    for index, page in enumerate(PDFPage.get_pages(fp, pagenos=set())):
        interpreter.process_page(page)
        # pbar.update(1)

        # Check if the maximum number of pages has been reached
        if index + 1 >= max_pages:
            break

    text = out_text.getvalue()

    fp.close()
    text_converter.close()
    out_text.close()

    return text

# %% [markdown]
# #### NLP Function

# %%
import re

def replace_newlines(text):
    # Replace newlines in the middle of a sentence with spaces
    text = re.sub(r'(?<!\n)\n(?!\n)', ' ', text)

    # Remove newlines at the end of a sentence
    text = re.sub(r'\n$', '', text)

    return text

from collections import Counter

def most_recurrent_locations(text: str) -> dict:
    # Load the pre-trained model
    nlp = spacy.load("en_core_web_sm")

    # Replace newlines in the text
    sample_text = replace_newlines(text)

    # Process the text
    doc = nlp(sample_text)

    # Find location words and their locations
    locations = [entity.text for entity in doc.ents if entity.label_ == "GPE" or entity.label_ == "LOC"]

    # Disregard strings that contain specific words
    disregarded_words = ['USA', 'United States', 'United States of America', 'North America', 'UNITED STATES', 'al.', 'US', "U.S.", 'the United States']
    locations = [location for location in locations if not any(word in location for word in disregarded_words)]

    # Count the frequency of each location
    location_counts = Counter(locations)

    # Sorting locations by frequency
    sorted_locations = sorted(location_counts.items(), key=lambda x: x[1], reverse=True)

    # Create a dictionary with 7 item (frequency) format
    first_elements = {f"{item} ({count})": count for item, count in sorted_locations[:7]}

    return first_elements

# %% [markdown]
# #### Processing Files

# %%
def get_pdf_file_names():
    pdf_files = glob.glob("/Users/othmaneechchabi/Desktop/Research/Data+/Climate+/SWISLTR/script/combined_data/*.pdf")
    return pdf_files

# Define a function to process a single file
def process_pdf_file(file):
    content = get_pdf_file_content(file)
    output_dict = most_recurrent_locations(content)
    return file, list(output_dict.keys())

pdf_files = get_pdf_file_names()
list_of_lists = []

# %% [markdown]
# #### Multithreading

# %%
filename = []
# Create a ThreadPoolExecutor with the maximum number of worker threads
with concurrent.futures.ThreadPoolExecutor() as executor:
    # Submit the file processing tasks to the executor
    future_results = [executor.submit(process_pdf_file, file) for file in pdf_files]

    # Use tqdm to track the progress of the tasks
    for future in tqdm(concurrent.futures.as_completed(future_results), total=len(future_results)):
        # Retrieve the result from the completed task and append it to the list
        list_of_lists.append(future.result()[1])
        filename.append(future.result()[0])

# Find the maximum number of elements in the lists
max_list_length = max(len(lst) for lst in list_of_lists)

# Add empty strings to lists lacking elements
for lst in list_of_lists:
    while len(lst) < max_list_length:
        lst.append('')

# Now all the lists inside list_of_lists have the same number of elements
# Out:
#  36%|███▌      | 77/213 [01:39<02:10,  1.04it/s] The PDF <_io.BufferedReader name='/Users/othmaneechchabi/Desktop/Research/Data+/Climate+/SWISLTR/script/combined_data/10.2118:176630-ms.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
# 100%|██████████| 213/213 [04:08<00:00,  1.17s/it]

# %%
# filename = []
# list_of_lists = []

# # Process each file sequentially
# for file in pdf_files:
#     result = process_pdf_file(file)
#     list_of_lists.append(result[1])
#     filename.append(result[0])

# # Find the maximum number of elements in the lists
# max_list_length = max(len(lst) for lst in list_of_lists)

# # Add empty strings to lists lacking elements
# for lst in list_of_lists:
#     while len(lst) < max_list_length:
#         lst.append('')


# pdf_files = glob.glob("PDF Papers (20)/*.pdf")
# file = pdf_files[0]
# text_file = open("sample.txt", "w")
# n = text_file.write(get_pdf_file_content(file))
# text_file.close()

# %% [markdown]
# #### 'list_of_lists' now contains the results from processing each PDF file

# %%
list_of_lists
# Out:
# [['Mogao (12)',
#   'Japan (5)',
#   'China (3)',
#   'Osaka (2)',
#   'Ito Misae (1)',
#   'Toyonaka (1)',
#   'Dunhuang city (1)'],
#  ['Africa (3)',
#   'London (2)',
#   'Brazil (1)',
#   'South Africa (1)',
#   'West Africa (1)',
#   'Uganda (1)',
#   'China (1)'],
#  ['River (6)',
#   'Australia (5)',
#   'I.D. (5)',
#   'Eldridge (1)',
#   'Talsma (1)',
#   'South (1)',
#   'New  South  Wales (1)'],
#  ['Oman (8)',
#   'El-Kaliouby (4)',
#   'Muscat (2)',
#   'Northern Oman (2)',
#   'J.D. (2)',
#   'Young (2)',
#   'Egypt (1)'],
#  ['the Colorado River (13)',
#   'Mexico (12)',
#   'Colorado (7)',
#   'the Gulf of California (7)',
#   'Nile (6)',
#   'Egypt (6)',
#   'Indus (5)'],
#  ['Guadalhorce River (12)',
#   'the Guadalhorce River (12)',
#   'Spain (7)',
#   'the Mediterranean Sea (6)',
#   'Europe (4)',
#   'Southern Spain (2)',
#   'Mediterranean (2)'],
#  ['Argentina (8)',
#   'Deregibus (6)',
#   'VA (4)',
#   'Sala (3)',
#   'Sanchez (3)',
#   'Danthonia (2)',
#   'Midland (2)'],
#  ['Portugal (3)',
#   'Oulu (1)',
#   'Finland (1)',
#   'Porto (1)',
#   'Khodaverdiloo (1)',
#   'Schofield (1)',
#   'Yoshii (1)'],
#  ['Germany (8)',
#   'the Wadden Sea (4)',
#   'Holt (2)',
#   'Eq (2)',
#   'Wadden (2)',
#   'Salem (2)',
#   'Radon (1)'],
#  ['Russia (12)',
#   'Boyarin (6)',
#   'Flagman (3)',
#   'Pi-ta (3)',
#   'the Russian Federation (2)',
#   'morphotype (2)',
#   'Krasnodar (2)'],
#  ['′′ (21)',
#   'Youpwe (14)',
#   'Douala (13)',
#   'Mirzavand (6)',
#   'N (6)',
#   'Shalem (4)',
#   'Wouri (4)'],
#  ['India (7)',
#   'Danda (5)',
#   'Bangladesh (2)',
#   'West Bengal (2)',
#   'Mousuni Island (2)',
#   'Haldia (2)',
#   'Kolkata (2)'],
#  ['Senegal (5)',
#   'West Africa (3)',
#   'Lausanne (1)',
#   'Switzerland (1)',
#   'Ivory Coast (1)',
#   'Puentes (1)',
#   'Tuong (1)'],
#  ['Australia (5)',
#   'River (4)',
#   'Overland (3)',
#   'South (2)',
#   'Values (2)',
#   'IV (2)',
#   'the River Murray Floodplain (1)'],
#  ['China (13)',
#   'SPIE Vol (8)',
#   'farmland (8)',
#   'Hetao (5)',
#   'Inner Mongolia (5)',
#   'the Yellow River (5)',
#   'Northern China (3)'],
#  ['China (3)',
#   'Japan (3)',
#   'Glycine (3)',
#   'Cox and Jolliff (3)',
#   'Arabidopsis (3)',
#   'Korea (2)',
#   'Australia (2)'],
#  ['Canada (5)',
#   'Arctic (5)',
#   'Mackenzie Delta (5)',
#   'The Mackenzie Delta (4)',
#   'the Mackenzie Delta (3)',
#   'Clarke (2)',
#   'Arctic delta (1)'],
#  ['Brazil (34)',
#   'Portugal (30)',
#   'Rio de Janeiro (24)',
#   'Estado (4)',
#   'Singreh (3)',
#   "Rio de Janeiro's (3)",
#   'Europe (2)'],
#  ['Economics (1)',
#   'CAPITAL (1)',
#   'the Soviet Union (1)',
#   'pp. (1)',
#   'United  States (1)',
#   'republics (1)',
#   ''],
#  ['DNRA (18)',
#   'China (13)',
#   '− (11)',
#   'N (6)',
#   'nirK (5)',
#   'Fuzhou (3)',
#   'Stockholm (2)'],
#  ['Argentina (6)',
#   'Chloris (5)',
#   'Paspalum (2)',
#   'Central Argentina (2)',
#   'Cynodon (2)',
#   'Verbena (2)',
#   'Hypochoeris (2)'],
#  ['Bedrich (19)',
#   'Czech Republic (4)',
#   'mg·l−1 (4)',
#   'Brno (3)',
#   'Tukey (3)',
#   'Placek A. (3)',
#   '1104–4290 (2)'],
#  ['cid:152 (7)',
#   'Uzbekistan (3)',
#   'Abutalieva (2)',
#   'the Aral Sea (2)',
#   'Samarkand (1)',
#   'F.B. (1)',
#   'E.B. (1)'],
#  ['NaCl (9)',
#   'Tukey (7)',
#   'NRT1.1-GFP (3)',
#   'Hangzhou (1)',
#   'China (1)',
#   'Cl− (1)',
#   'benthamiana (1)'],
#  ['Argentina (3)',
#   'B21 (3)',
#   'Taboada (2)',
#   'West (2)',
#   'Atlantic (2)',
#   'W. Germany (1)',
#   'Province (1)'],
#  ['NS (14)',
#   'NaCl (6)',
#   'Specifi (2)',
#   'MD (2)',
#   'NS\n\n (2)',
#   'NS NS (2)',
#   'Purvaja (2)'],
#  ['Maryland (9)',
#   'New York (7)',
#   'Virginia (7)',
#   'Florida (6)',
#   'New Brunswick (4)',
#   'KEARNEY (4)',
#   'Copenheaver (3)'],
#  ['the West Coast (1)', 'Florida (1)', 'San Bernardino (1)', '', '', '', ''],
#  ['Portugal (16)',
#   'Italy (7)',
#   'Porto (7)',
#   'Rome (3)',
#   'Egypt (3)',
#   'France (3)',
#   'Germany (3)'],
#  ['Spain (7)',
#   'Madrid (5)',
#   'Barcelona (2)',
#   'Central (1)',
#   'M.C. (1)',
#   'Escuela (1)',
#   'Les  Ulis (1)'],
#  ['Dagestan (6)',
#   'pp. (5)',
#   'Moscow (5)',
#   'Makhachkala (3)',
#   'Caspian Sea (3)',
#   'the Caspian Sea (2)',
#   'Kaspiiskoe (2)'],
#  ['Arctic (10)',
#   'Venice (5)',
#   'Portugal (2)',
#   'the Gulf of Mexico (2)',
#   'Thailand (2)',
#   'Honduras (2)',
#   'the Black Sea (2)'],
#  ['China (5)',
#   'the Keriya River (5)',
#   'Keriya (3)',
#   'ArcGIS10.1 (2)',
#   'HOBO (2)',
#   'Israel (2)',
#   'Iran (2)'],
#  ['Tamarix (19)',
#   'Stromberg (7)',
#   'Denver (4)',
#   'Smith (4)',
#   'Montana (3)',
#   'Sexton (2)',
#   '0e15 (2)'],
#  ['GGPP (4)',
#   'Santa Catarina (3)',
#   'Brazil (3)',
#   'Carotenoids (3)',
#   'Grifﬁths et al (2)',
#   'Seto (2)',
#   'Nadolska (1)'],
#  ['L-1 (10)',
#   'Biogeochemistry (4)',
#   'North Carolina (3)',
#   'NC (2)',
#   'Columbia (2)',
#   'MD (2)',
#   'N2O (1)'],
#  ['Nicaragua (9)',
#   'Central America (4)',
#   'Pacific (4)',
#   'the Pacific Coast (3)',
#   'Netherlands (3)',
#   'Atlantic (3)',
#   'East (3)'],
#  ['the Altamaha River (7)',
#   'HS(cid:1 (4)',
#   'N (4)',
#   'Georgia (3)',
#   'Canfield (3)',
#   'Weston (2)',
#   'Altamaha River (2)'],
#  ['Europe (2)',
#   'Germany (2)',
#   'CONCEPTS (1)',
#   'United  States (1)',
#   'United  Kingdom (1)',
#   'Netherlands (1)',
#   'Soil (1)'],
#  ['Brazil (10)',
#   'Ceará (3)',
#   'Spain (3)',
#   'Hadlich et al (3)',
#   'Australia (2)',
#   'the Acaraú River (2)',
#   'the Acaraú Basin (2)'],
#  ['Louisiana (16)',
#   'eastern delta (3)',
#   'Coastal Wetlands: A (2)',
#   'West Palm Beach (2)',
#   'Florida (2)',
#   'Wetlands (2)',
#   'Black (2)'],
#  ['Egypt (30)',
#   'Nile Delta (6)',
#   'Mediterranean (3)',
#   'the Nile Delta (3)',
#   'Africa (2)',
#   'the Nile River (2)',
#   'the River Nile (1)'],
#  ['Paciﬁc Ocean (2)',
#   'Nunn (2)',
#   'Kiribati (2)',
#   'Weir (2)',
#   'Virani (2)',
#   'Singapore (1)',
#   'Paciﬁc (1)'],
#  ['Sci. (14)',
#   'Europe (13)',
#   'Mediterranean (11)',
#   'Ludwig (3)',
#   'Cambridge (3)',
#   'Brussels (2)',
#   'HighNoon (2)'],
#  ['Arctic (20)',
#   'Canada (14)',
#   'Mackenzie Delta (11)',
#   'M.F.J.P. (7)',
#   'the Mackenzie Delta (7)',
#   'J.R.T. (5)',
#   'Delta (4)'],
#  ['Indus (12)',
#   'Macklin (10)',
#   'Ashworth (9)',
#   'Nile (6)',
#   'Lewin (6)',
#   'Field (3)',
#   'Latrubesse (3)'],
#  ['Australia (6)',
#   'Ruprecht (4)',
#   'Dogramaci (3)',
#   'WA (2)',
#   'India (2)',
#   'South Western Australia (2)',
#   'Africa (2)'],
#  ['Luxor (9)',
#   'Egypt (6)',
#   'the Nile River (6)',
#   'the Nile Valley (5)',
#   'the west bank (4)',
#   'Nile River (3)',
#   'Cairo (3)'],
#  ['Smith (7)',
#   'New Jersey (6)',
#   'the Delaware Bay (4)',
#   'Sebold (4)',
#   'Delaware (3)',
#   'Weishar (3)',
#   'Warren (3)'],
#  ['Brazil (10)',
#   'Santa Barbara (7)',
#   'Hadlich et al (7)',
#   'Ceará (3)',
#   'Lana (2)',
#   'Africa (2)',
#   'Madagascar (2)'],
#  ['Delft (3)',
#   'the Marshall Islands (2)',
#   'Pomeroy (2)',
#   'The Netherlands (1)',
#   'Netherlands (1)',
#   'Singapore (1)',
#   'Rotterdam (1)'],
#  ['Ganga (17)',
#   'Ganga Plain (14)',
#   'India (9)',
#   'the Ganga Plain (4)',
#   'Marginal (3)',
#   'Bihar (2)',
#   'Yamuna (2)'],
#  ['', '', '', '', '', '', ''],
#  ['California (22)',
#   'MO (3)',
#   'Scardaci (3)',
#   'Sacramento (2)',
#   'Valley (2)',
#   'Kansas City (2)',
#   'Tanji (2)'],
#  ['Australia (26)',
#   'Murray River (7)',
#   'Ogden (5)',
#   'Stuttgart (4)',
#   'Murrumbidgee (3)',
#   'Coorong (3)',
#   'pp (3)'],
#  ['Phragmites (4)',
#   'Smith (4)',
#   'Chesapeake\tBay (3)',
#   'Washington (2)',
#   'Maryland (2)',
#   'Marsh (2)',
#   'Canoco (2)'],
#  ['Argentina (4)',
#   'Rodríguez (2)',
#   'San Martín 4453 (1)',
#   'Buenos Aires (1)',
#   'Freemark (1)',
#   'Boutin (1)',
#   'McLaughlin (1)'],
#  ['Mediterranean (5)',
#   'Morocco (3)',
#   'the Tahadart Basin (3)',
#   'PRUDENCE (3)',
#   'Smith (3)',
#   'Carneiro (2)',
#   'North Africa (2)'],
#  ['Australia (4)',
#   'Earth (2)',
#   'Smith (2)',
#   'England (1)',
#   'London (1)',
#   '3JH (1)',
#   'UK (1)'],
#  ['Israel (3)',
#   'Himalayas (1)',
#   'Sahara (1)',
#   'Algeria (1)',
#   'Bighorn Basin (1)',
#   'Wyoming (1)',
#   'Middle East (1)'],
#  ['n    (4)',
#   'Greenland (4)',
#   'Louisiana (4)',
#   'Mississippi (3)',
#   'Nile (3)',
#   'Australia (3)',
#   'Beach (2)'],
#  ['Earth (6)',
#   'Volga (5)',
#   'Western Kazakhstan (5)',
#   'Kazakhstan (3)',
#   'Russia (2)',
#   'L S (1)',
#   'Lobnya (1)'],
#  ['UK (2)',
#   'Greenville (1)',
#   'North Carolina (1)',
#   'North  Carolina (1)',
#   'Belfast (1)',
#   'Maui (1)',
#   'Hawaii (1)'],
#  ['Boggy (20)',
#   'Australia (5)',
#   'Zooplankton (4)',
#   'L-1 (4)',
#   'C. ﬂuviatilis (4)',
#   'Mundoo Island (3)',
#   'Lake Alexandrina (3)'],
#  ['Mekong (25)',
#   'Lauri (13)',
#   'Mekong River (11)',
#   'Sci. (7)',
#   'Hydrol (7)',
#   'Cambodia (5)',
#   'MRC (4)'],
#  ['China (8)',
#   'Yellow River Delta (5)',
#   'Yellow River (3)',
#   'Beijing (2)',
#   'Dongying (2)',
#   'Hong Kong (1)',
#   'Inc. (1)'],
#  ['Lake Salvador (11)',
#   'Louisiana (3)',
#   'the Mississippi River (3)',
#   'Dawson (3)',
#   'Barataria (3)',
#   'Baton Rouge (2)',
#   'LA (2)'],
#  ['Atulia (22)',
#   'Bangladesh (16)',
#   'Burigoaliny (10)',
#   'Gabura (8)',
#   'M.A. Rakib (4)',
#   'Kashiwanoha (3)',
#   'Kashiwa (3)'],
#  ['Bangladesh (11)',
#   'the Bay of Bengal (10)',
#   'West Bengal (4)',
#   'Bay of Bengal (4)',
#   'Haldia (4)',
#   'India (3)',
#   'UK (3)'],
#  ['France (4)',
#   'West Africa (3)',
#   'Odoulami (2)',
#   'the Atlantic Ocean (2)',
#   'Socohou (1)',
#   'Roland (1)',
#   'Montpellier (1)'],
#  ['Egypt (7)',
#   'Mut (4)',
#   'El-Qalamun (4)',
#   'Mut City (3)',
#   'Taref (2)',
#   'Dakhla (2)',
#   'NE (2)'],
#  ['', '', '', '', '', '', ''],
#  ['Bangkok (6)',
#   'Tokyo (3)',
#   'Shanghai (3)',
#   'Sydney (3)',
#   'London (2)',
#   'Netherlands (2)',
#   'Greenland (2)'],
#  ['T. Vegas-Vilarrúbia (8)',
#   'Barcelona (7)',
#   'Orinoco Delta (6)',
#   'Spain (4)',
#   'Wignall (4)',
#   'Vegas-Vilarrúbia (4)',
#   'Orinoco (3)'],
#  ['Louisiana (13)',
#   'South Carolina (12)',
#   'Georgia (10)',
#   'Waccamaw (5)',
#   'Waccamaw River (2)',
#   'Winyah Bay (2)',
#   'Savannah River (2)'],
#  ['the Aral Sea (3)',
#   'Tashkent (2)',
#   'Samarkand (1)',
#   'Uzbekistan (1)',
#   'V.I.Aravina (1)',
#   'N.I. Khojibaev (1)',
#   'U. U. Umarova (1)'],
#  ['China (4)',
#   'Vigna (3)',
#   'Tanacetum (3)',
#   'Zea (3)',
#   'Triticum (2)',
#   'Brassica (2)',
#   'Helianthus (2)'],
#  ['Thailand (3)',
#   'Northeast Thailand (2)',
#   'Ghassemi (2)',
#   'Bernardeau (2)',
#   'NE Thailand (1)',
#   'Bangkok (1)',
#   'Kaen (1)'],
#  ['Earth (5)',
#   'Russia (4)',
#   'Moscow (3)',
#   'N.I. (1)',
#   'NM (1)',
#   'Reshetkina (1)',
#   'Western Siberia (1)'],
#  ['Russia (2)',
#   'M.A. (2)',
#   'Marina (1)',
#   'Tyumen (1)',
#   'Hayfield (1)',
#   'Pastureland (1)',
#   'A.A. (1)'],
#  ['the Tarim River (4)',
#   'China (3)',
#   'Xinjiang (1)',
#   'The Tarim River (1)',
#   'Logan (1)',
#   'UT (1)',
#   'Malvern (1)'],
#  ['cid:97)(cid:115 (20)',
#   'cid:119)(cid:97)(cid:115 (11)',
#   'cid:97)(cid:108)(cid:115)(cid:111 (8)',
#   'cid:84)(cid:104)(cid:105)(cid:115 (5)',
#   'cid:115)(cid:117)(cid:114)(cid:103)(cid:101)(cid:115 (3)',
#   'cid:76)(cid:97)(cid:103)(cid:111)(cid:111)(cid:110)(cid:115 (3)',
#   'France (2)'],
#  ['Sorghum (13)',
#   'Maryland (7)',
#   'Tester (7)',
#   'Kielen (7)',
#   'Tanji (6)',
#   'MD (4)',
#   'Qadir (3)'],
#  ['Africa (15)',
#   'Kenya (4)',
#   'AFRICA (3)',
#   'Nairobi (2)',
#   'Gent (2)',
#   'Belgium (2)',
#   'England (1)'],
#  ['Moscow (1)',
#   'Russia (1)',
#   'Eastern Siberia (1)',
#   'mD. (1)',
#   'NaCl (1)',
#   '',
#   ''],
#  ['n.s. (25)',
#   'Mo (13)',
#   'Na (5)',
#   'Zn (5)',
#   'Hungary (4)',
#   'Cu (4)',
#   'Budapest (1)'],
#  ['Vietnam (11)',
#   'Japan (8)',
#   'Tetsuhiro (3)',
#   'Kyoto (3)',
#   'Tokyo (3)',
#   'Shimadzu (2)',
#   'Quang Dien (1)'],
#  ['Egypt (38)',
#   'Nile (20)',
#   'the Nile Delta (6)',
#   'Mediterranean (4)',
#   'Aswan (4)',
#   'Delta (4)',
#   'Cairo (4)'],
#  ['Mekong (43)',
#   'Utrecht (2)',
#   'Vietnam (2)',
#   'Zoccarato (2)',
#   'delta (2)',
#   'Vermeulen (2)',
#   'Minderhoud (2)'],
#  ['Mekong (8)',
#   'Vietnam (8)',
#   'Ho Chi Minh City (3)',
#   'Vermeulen (3)',
#   'Minh (2)',
#   'Download (1)',
#   'California (1)'],
#  ['Delta (10)',
#   'Netherlands (9)',
#   'River (4)',
#   'DC (3)',
#   'Snellen (2)',
#   'Termeer (2)',
#   'the  DC (2)'],
#  ['Na+/K+ (6)',
#   'India (3)',
#   'Leghemoglobin (2)',
#   'Kukreja (2)',
#   'Cicer (1)',
#   'Gogorcena (1)',
#   'Wescor (1)'],
#  ['Mekong (7)',
#   'China (6)',
#   'Yangtze (5)',
#   'Mississippi (5)',
#   'the Mississippi River Delta (5)',
#   'Magdalena (4)',
#   'India (4)'],
#  ['n    (4)',
#   'Greenland (4)',
#   'Louisiana (4)',
#   'Mississippi (3)',
#   'Nile (3)',
#   'Australia (3)',
#   'Beach (2)'],
#  ['Mirzavand (14)',
#   'Iran (4)',
#   'Kashan (2)',
#   'Tehran (2)',
#   'Yaqing (2)',
#   'Deverel (2)',
#   'Gallanthine (2)'],
#  ['Mekong (12)',
#   'BP (7)',
#   'Vietnam (5)',
#   'kPa (4)',
#   'Italy (2)',
#   'Utrecht (2)',
#   'The Netherlands (2)'],
#  ['Delaware (4)',
#   'KS (4)',
#   'Armas (2)',
#   'Pugnaire (2)',
#   'Earth (1)',
#   'Warren (1)',
#   'the East coast (1)'],
#  ['South Africa (9)',
#   'South (3)',
#   'Africa (3)',
#   'Talbot (3)',
#   'i.a. (2)',
#   'Cape (2)',
#   'Zostera (2)'],
#  ['New England (9)',
#   'Niering (8)',
#   'Warren (8)',
#   'C.R. (7)',
#   'Connecticut (7)',
#   'Smith (4)',
#   'C.S. (4)'],
#  ['the North Basin (20)',
#   'the South Basin (19)',
#   'the River Murray (12)',
#   'River Murray (11)',
#   'South Basin (10)',
#   'North (10)',
#   'South (9)'],
#  ['Central Argentina (5)',
#   'NS (3)',
#   'Argentina (2)',
#   'Cynodon (2)',
#   'WTEC (2)',
#   'WT (2)',
#   'Veterinaria (1)'],
#  ['Kazakhstan (7)',
#   'Kazalinsk (6)',
#   'Amsterdam (1)',
#   'The Netherlands (1)',
#   'N (1)',
#   'V.M. (1)',
#   'North Kazakhstan (1)'],
#  ['Australia (10)',
#   'Vallisneria (7)',
#   'Brock et al (3)',
#   'Victoria (3)',
#   'Clayton (1)',
#   'Smith (1)',
#   'south-east (1)'],
#  ['the Huolin River (5)',
#   'Huolin River (4)',
#   'Da’an (4)',
#   'China (2)',
#   'The Huolin River (2)',
#   'the Chagan Lake (2)',
#   'Criteria (2)'],
#  ['Mahanadi (6)',
#   'Zarﬂ (5)',
#   'Volta (4)',
#   'Highﬁeld (3)',
#   'Southampton (3)',
#   'India (3)',
#   'UK (2)'],
#  ['Nhecolândia (9)',
#   'Brazil (5)',
#   'Banhado (4)',
#   'Kellog (3)',
#   "Zaidel'man (3)",
#   'Almeida (3)',
#   'Banhado lake (3)'],
#  ['the Salado River (6)',
#   'Salado-River (4)',
#   'Salado-River basin (3)',
#   'Argentina (3)',
#   'Kefford (3)',
#   'Salado (3)',
#   'Bragado (3)'],
#  ['the Aral Sea (17)',
#   'Aral Sea (10)',
#   'the Great Sea (9)',
#   'Great Sea (8)',
#   'Small Sea (3)',
#   'the Small Sea (3)',
#   'Vozrozhdeniya (3)'],
#  ['Greenland (7)',
#   'Calcarina (5)',
#   'the Republic of the Marshall Islands (3)',
#   'West Antarctic (2)',
#   'Jabat Island (2)',
#   'Japan (2)',
#   'Majuro (2)'],
#  ['Portugal (5)',
#   'T. (5)',
#   'A.J. (4)',
#   'Reinecke (4)',
#   'NaCl (3)',
#   'Princz (3)',
#   'Eisenia (3)'],
#  ['Australia (4)',
#   'Thorburn (2)',
#   'Broadbridge (2)',
#   'I.D. Jollya (1)',
#   'Agriculture (1)',
#   'Bruxner Highway (1)',
#   'Wollongbar (1)'],
#  ['Chad (21)',
#   'Lake Chad (11)',
#   'Africa (4)',
#   'the Sahara Desert (3)',
#   'Massif (3)',
#   'Niger (2)',
#   'Nigeria (2)'],
#  ['Mekong (38)',
#   'Vietnam (14)',
#   'Cambodia (11)',
#   'Delta (10)',
#   'China (9)',
#   'Laos (8)',
#   'MT (8)'],
#  ['UK (10)',
#   'M.J. (5)',
#   'Choy (4)',
#   'Scotland (3)',
#   'Strontium (3)',
#   'Qafoku (3)',
#   'Livens (3)'],
#  ['Nanjing (14)',
#   'China (14)',
#   '+  T37 (6)',
#   'Jiangsu (5)',
#   'Japan (5)',
#   'Rhizoctonia (4)',
#   'Province (2)'],
#  ['Tamarix (5)',
#   'Italy (3)',
#   'Germany (3)',
#   'Mediterranean (2)',
#   'Kozlowski (1)',
#   'Flowers (1)',
#   'Field (1)'],
#  ['Spain (7)',
#   'PN (7)',
#   'MM (4)',
#   'Plankton (2)',
#   'National Park (1)',
#   'Paterna (1)',
#   'Madrid (1)'],
#  ['R.J. (6)',
#   'New Orleans (3)',
#   'pp. (3)',
#   'Woodworth (3)',
#   'Bangkok (3)',
#   'Wong (2)',
#   'Myanmar (2)'],
#  ['kPa (4)',
#   'Australia (4)',
#   'Smith (2)',
#   'pp. (2)',
#   'Mclntyre (2)',
#   'D.S. (2)',
#   'Ontario (1)'],
#  ['Argentina (15)',
#   'N (15)',
#   'E.C. (9)',
#   'Taboada (8)',
#   'R.S. (5)',
#   'Facelli (4)',
#   'Alconada (4)'],
#  ['the Kerkennah Islands (9)',
#   'Kerkennah (4)',
#   'Tunisia (3)',
#   'Moscow (2)',
#   'the Kerkennah archipelago (2)',
#   'Chergui (2)',
#   'Russia (1)'],
#  ['Australia (9)',
#   'Casuarina (7)',
#   'Armidale (5)',
#   'WA (3)',
#   'Toolibin Lake (3)',
#   'Delft (3)',
#   'The Netherlands (3)'],
#  ['New Zealand (10)',
#   'Kaiaua (6)',
#   'Tchouaffe (3)',
#   'Cazenave (2)',
#   'n.d. n.d. n.d. n.d. (2)',
#   'Hamilton City (1)',
#   'North Island (1)'],
#  ['pp. (7)',
#   'Starodubtsev (6)',
#   'Ili (4)',
#   'Kapchagai (3)',
#   'Moscow (3)',
#   'Bogdanets (3)',
#   'the Ili R. (2)'],
#  ['India (12)',
#   'Pakistan (11)',
#   'South Asia (9)',
#   'Indus (5)',
#   'Asia (3)',
#   'Earth (2)',
#   'Bangladesh (2)'],
#  ['Australia (3)',
#   'the Murray River (3)',
#   'the River Murray (2)',
#   'Thorburn (2)',
#   'Netherlands (1)',
#   'New South Wales (1)',
#   'Punkah Creek (1)'],
#  ['UK (14)',
#   'Lincolnshire (7)',
#   'North Sea (5)',
#   'the United Kingdom (3)',
#   'United Kingdom (2)',
#   'the North Sea (2)',
#   'farmland (2)'],
#  ['Aral Sea (13)',
#   'Central Asia (2)',
#   'the Aral Sea (2)',
#   'Israel (1)',
#   'The Aral Sea (1)',
#   'Micklin (1)',
#   'Stulina (1)'],
#  ['Lake Jormasj€arvi (17)',
#   'Finland (5)',
#   'the Tuhkajoki River (4)',
#   'Kauppila (3)',
#   'Lake Jor- masj€arvi (3)',
#   'Tuhkajoki River (3)',
#   'NC (2)'],
#  ['China (9)',
#   'IA (6)',
#   'lA (4)',
#   "Xi'an (2)",
#   'Shaanxi (2)',
#   'Yeyuhe (2)',
#   'Qihe (2)'],
#  ['India (43)',
#   'Gujarat (12)',
#   'Kumar (8)',
#   'West Bengal (5)',
#   'Qadir (4)',
#   'Rajasthan (4)',
#   'Karnataka (4)'],
#  ['the Republic of Adygea (12)',
#   'the Republic of Adygea Under Exogenous Geological Processes (4)',
#   'earth (4)',
#   'Russian Federation (3)',
#   'Giaginsky District (2)',
#   'the Republic of Adygea 3 Soil Degradation Due to (1)',
#   'Moscow (1)'],
#  ['Tsimlyansk (11)',
#   'Russia (3)',
#   'TsP12 (3)',
#   'N.A. Volkova (1)',
#   'pp. (1)',
#   'Moscow (1)',
#   'Rostovskaya (1)'],
#  ['N (5)',
#   'Germany (5)',
#   'CW (2)',
#   'Ks (2)',
#   'Earth (1)',
#   '−1 (1)',
#   'Greifswald (1)'],
#  ['Germany (4)',
#   'Denmark (3)',
#   'Crawley (3)',
#   'Australia (3)',
#   'mM (3)',
#   'Neuhofen (2)',
#   'kPa (2)'],
#  ['North Carolina (8)',
#   'Bhattachan (3)',
#   'North  Carolina (3)',
#   'Haywood (2)',
#   'Netherlands (2)',
#   'the Albemarle Sound (2)',
#   'ArcGIS (2)'],
#  ['India (6)',
#   'the Bay of Bengal (4)',
#   'Puri (4)',
#   'Kendrapara (4)',
#   'Odisha (3)',
#   'Khordha (3)',
#   'Bhadrak (3)'],
#  ['KC (10)',
#   'cid:17)2 (5)',
#   'Triticum (2)',
#   'Netherlands (1)',
#   'Assiut (1)',
#   'Egypt (1)',
#   'Sigma (1)'],
#  ['Earth (7)',
#   'Russia (5)',
#   'Moscow (4)',
#   'the Republic of Kalmykia (3)',
#   'Yashkul (1)',
#   'East (1)',
#   'the Caspian Sea (1)'],
#  ['Kuiseb (12)',
#   'Namibia (6)',
#   'the Namib Desert (4)',
#   'Lower Kuiseb (4)',
#   'Campana (4)',
#   'Germany (2)',
#   'Israel (2)'],
#  ['Bangladesh (7)',
#   'Gorai river (4)',
#   'South West (4)',
#   'the Bay of Bengal (4)',
#   'node (3)',
#   'Kamarkhali (3)',
#   'Gorai (2)'],
#  ['Egypt (13)',
#   'Moscow (1)',
#   'Russia (1)',
#   'Zagazig (1)',
#   'Cham (1)',
#   'Switzerland (1)',
#   'the Middle Ages (1)'],
#  ['Moscow (5)',
#   'Astrakhan (4)',
#   'Barfon (4)',
#   'the Baer Mounds (3)',
#   'Russia (3)',
#   'Mounds (3)',
#   'pp. (2)'],
#  ['Australia (18)',
#   'Basin (5)',
#   'Groups (2)',
#   'J.R. (1)',
#   'C.A. (1)',
#   'Canberra (1)',
#   'IV (1)'],
#  ['Namibia (12)',
#   'South Africa (9)',
#   'Southern Africa (8)',
#   'Swaziland (5)',
#   'Botswana (4)',
#   'Zimbabwe (3)',
#   'Southern Africa  \n\n (3)'],
#  ['the Tigris River (8)',
#   'Tigris River (7)',
#   'the Arabian Gulf (6)',
#   'HEC (6)',
#   'Basrah Province (3)',
#   'the River-Surveyor (3)',
#   'Euphrates (3)'],
#  ['Australia (15)',
#   'Albany (3)',
#   'Pannell (2)',
#   'South Australia (2)',
#   'Laslett (2)',
#   'Mediterranean (2)',
#   'Bentley (1)'],
#  ['North Carolina (4)',
#   'Biogeochemistry (4)',
#   'the Albemarle Sound (4)',
#   'NC (3)',
#   'L-1 (3)',
#   'Ardo´n (2)',
#   'Ohio (2)'],
#  ['the Yellow River Delta (12)',
#   'China (5)',
#   'Yellow River Delta (5)',
#   'the Yellow River (3)',
#   'Beijing (2)',
#   'Shandong Province (2)',
#   'Dongying (2)'],
#  ['Europe (6)',
#   'China (5)',
#   'India (4)',
#   'earth (2)',
#   'Pakistan (2)',
#   'Iowa (2)',
#   'United  States (2)'],
#  ['the River Murray (10)',
#   'Australia (5)',
#   'Monoman Island (3)',
#   'River Murray (2)',
#   'MDBC (2)',
#   'Canberra (1)',
#   'Groundwater (1)'],
#  ['Paciﬁc Island (18)',
#   'Nunn (15)',
#   'the Paciﬁc Islands (9)',
#   'Fiji (8)',
#   'Paciﬁc Islands (4)',
#   'Paciﬁc (4)',
#   'Micronesia (2)'],
#  ['Bangladesh (13)',
#   'Japan (4)',
#   'Kashiwanoha (3)',
#   'Kashiwa (3)',
#   'M.A. (2)',
#   'Md. (2)',
#   'M.A. Rakib (1)'],
#  ['Chongming (15)',
#   'China (9)',
#   'Dongtan (6)',
#   'Shanghai (3)',
#   'the Yangtze River Estuary (3)',
#   'Phragmites (2)',
#   'Yangtze (2)'],
#  ['Ostia (26)',
#   'Rome (16)',
#   'Ostia Antica (11)',
#   'AQUA2015 (6)',
#   'Italy (5)',
#   'Roma (5)',
#   'Tiber River (5)'],
#  ['El Paso (11)',
#   'Mexico (9)',
#   'the Middle Rio Grande (3)',
#   'New Mexico (3)',
#   'the El Paso (2)',
#   'the Middle East (2)',
#   'Africa (2)'],
#  ['Basin (10)',
#   'Universidad (7)',
#   'Australia (6)',
#   'the Murray River (3)',
#   'New South Wales (2)',
#   'Victoria (2)',
#   'Wakool River (2)'],
#  ['Washington, DC: (5)',
#   'Costa Rica (3)',
#   'New York City (3)',
#   'Earth (2)',
#   'CA (1)',
#   'Coastal (1)',
#   'California (1)'],
#  ['Overton (9)',
#   'South Australia (7)',
#   'Modelling (5)',
#   'Australia (3)',
#   'the River Murray (3)',
#   'Urrbrae (2)',
#   'New South Wales (2)'],
#  ['North Carolina (4)',
#   'Gull Rock (3)',
#   'Swanquarter (3)',
#   'Swanquar- (2)',
#   'Palmetto Peartree Preserve (2)',
#   '0.01b (2)',
#   'Raleigh (1)'],
#  ['Bangladesh (17)',
#   'UK (2)',
#   'Khulna (2)',
#   'Barisal (2)',
#   'Modelling (1)',
#   'Southampton (1)',
#   'Liverpool (1)'],
#  ['Alaska (4)',
#   'Arctic (1)',
#   'Betula (1)',
#   'Anchorage (1)',
#   'GA (1)',
#   'Grid (1)',
#   'KME (1)'],
#  ['North Carolina (10)',
#   'North  Carolina (7)',
#   'North Carolina’s (3)',
#   'NC (3)',
#   'Battaglia (3)',
#   'Coastal Plain (3)',
#   'Liquidambar (3)'],
#  ['Iraq (3)',
#   'Boca Raton (1)',
#   'Auckland, New Zealand (1)',
#   'Cham (1)',
#   'Switzerland (1)',
#   '',
#   ''],
#  ['Norfolk (7)',
#   'Australia (5)',
#   'France (5)',
#   'UK (4)',
#   'The Netherlands (3)',
#   'Europe (3)',
#   'Berlin (2)'],
#  ['North Carolina (4)',
#   'HUC (4)',
#   'Louisiana (3)',
#   'Gulf (2)',
#   'Landsat (2)',
#   'Akaike (2)',
#   'Charlottesville (1)'],
#  ['Nueces River (8)',
#   'Texas (4)',
#   'Br− (3)',
#   'Shafer (2)',
#   'Nueces Bay (2)',
#   'Hopkins (2)',
#   '− (2)'],
#  ['Tamarix (10)',
#   'Netherlands (4)',
#   'Italy (3)',
#   'Mediterranean (3)',
#   'N (3)',
#   'Viterbo (1)',
#   'T. africana (1)'],
#  ['Tucson (3)',
#   'the Lower Colorado River (3)',
#   'Nagler (3)',
#   'Parker (3)',
#   'Hoover Dam (2)',
#   'the Colorado River (2)',
#   'Arizona (2)'],
#  ['Panta (2)',
#   'BN1 9QG (1)',
#   'UK (1)',
#   'Vito (1)',
#   'Calabria (1)',
#   'Italy (1)',
#   'Limonium (1)'],
#  ['Limonium (4)',
#   'Bergh (3)',
#   'Netherlands (2)',
#   '+  H.  portulacoides (2)',
#   'The Netherlands \n\nKeywords (1)',
#   'Maarel (1)',
#   'Vegetatio (1)'],
#  ['Lake Eyre (38)',
#   'Australia (14)',
#   'Cenozoic (10)',
#   'd2H (8)',
#   'the Lake Eyre Basin (5)',
#   'the Diamantina River (4)',
#   'Melbourne (3)'],
#  ['River Murray (10)',
#   'the River Murray (6)',
#   'Australia (4)',
#   'the North Basin (4)',
#   'the South Basin (4)',
#   'Nielsen (3)',
#   'Loveday (3)'],
#  ['più (11)',
#   'N.3 (7)',
#   'la (6)',
#   'Europa (4)',
#   'sia (4)',
#   'necessità (3)',
#   'oltre (3)'],
#  ['Venice (18)',
#   'Italy (6)',
#   'Zezza (3)',
#   'the Adriatic Sea (2)',
#   'Adriatic Sea (2)',
#   'Kouzana (1)',
#   'Rapaglia (1)'],
#  ['Weston (5)',
#   'Bridgham (3)',
#   'South Carolina (2)',
#   'Richmond (2)',
#   'Virginia (2)',
#   'the Waccamaw River (2)',
#   'Waccamaw River (2)'],
#  ['New York (4)',
#   'Bangkok (4)',
#   'Grand Isle (3)',
#   'London (2)',
#   'Tokyo (2)',
#   'Shanghai (2)',
#   'Nicholls (2)'],
#  ['L-1 (5)',
#   'Weston (4)',
#   'North Carolina (3)',
#   'N2O (3)',
#   'California (2)',
#   'Mason (2)',
#   'Ohio (2)'],
#  ['Senegal River (31)',
#   'the Senegal River (26)',
#   'Senegal (12)',
#   'Mauritania (8)',
#   'Guinea (7)',
#   'Baﬁng (6)',
#   'Bakoye (6)'],
#  ['North Carolina (7)',
#   'Bird (2)',
#   'the Albemarle Sound (1)',
#   'the Croatan Sound (1)',
#   'the Pamlico Sound (1)',
#   'the Neuse River (1)',
#   'Blue Grosbeak (1)'],
#  ['Bangladesh (6)',
#   'Shora (6)',
#   'Sydney (3)',
#   'New South Wales (3)',
#   'Australia (3)',
#   'leiden (1)',
#   'Earth (1)'],
#  ['Paciﬁc Ocean (3)',
#   'Pokfulam (2)',
#   'Hong Kong (2)',
#   'Underwood (2)',
#   'Kiribati (2)',
#   'Dubai (1)',
#   'United Arab Emirates (1)'],
#  ['the Rhone River (13)',
#   'the Rhone Delta (4)',
#   'France (3)',
#   'United Kingdom (3)',
#   'Mediterranean (3)',
#   'the Little Ice Age (2)',
#   'The Rhone River (2)'],
#  ['Florida (15)',
#   'Louisiana (14)',
#   'Mississippi (10)',
#   'Texas (8)',
#   'Gulf of Mexico (8)',
#   'LA (8)',
#   'Alabama (6)'],
#  ['Germany (4)',
#   'Pott (2)',
#   'T. (1)',
#   'Oldenburg (1)',
#   'the North Sea (1)',
#   'Lebbe (1)',
#   'Klassen (1)'],
#  ['cid:6)(cid:19)9(cid:10)(cid:3 (3)',
#   'cid:4)78(cid:14)(cid:13 (2)',
#   'cid:6)(cid:7 (2)',
#   'cid:6)(cid:26)(cid:7 (2)',
#   'cid:6)(cid:26)(cid:7)(cid:12)(cid:15)(cid:16)(cid:4)(cid:3)(cid:5)(cid:2)(cid:16)(cid:7)(cid:5)(cid:19)(cid:10 (1)',
#   'cid:21)(cid:4)1 (1)',
#   'cid:6)(cid:9)(cid:3 (1)'],
#  ['Barcelona (8)',
#   'Sci. (7)',
#   'Spain (5)',
#   'Hydrol (5)',
#   'Mediterranean (2)',
#   'France (2)',
#   'Greenhalgh (2)'],
#  ['Australia (12)',
#   'South (10)',
#   'Alaghmand (10)',
#   'Holland (7)',
#   'Malaysia (4)',
#   'Lower  Murray  River (3)',
#   'Newton (3)'],
#  ['Thorburn (6)',
#   'Australia (3)',
#   'Broadbridge (3)',
#   'Zf (3)',
#   'P.J. (2)',
#   'Walker (2)',
#   'Jolly (2)'],
#  ['China (6)',
#   'the Yellow River (5)',
#   'the Yellow River Delta (4)',
#   'Eq (2)',
#   'Eqs (2)',
#   'Beijing (1)',
#   'Kumar (1)'],
#  ['Bangladesh (17)',
#   'Sci. (7)',
#   'LGM (3)',
#   'Utrecht (2)',
#   'Netherlands (2)',
#   'Hydrol (2)',
#   'N5 (2)'],
#  ['Brazil (5)',
#   '−1 (4)',
#   'Antipov (4)',
#   'Salina (4)',
#   'Banhado lake (4)',
#   'Nhecolândia (3)',
#   'Fernandes (3)'],
#  ['Jiaojia (22)',
#   'China (5)',
#   'Quaternary (3)',
#   'Tanlu (2)',
#   'min(xi (2)',
#   '⎥ (2)',
#   'Germany (1)'],
#  ['Argentina (3)',
#   'UG (3)',
#   'Jackson (2)',
#   'Australia (2)',
#   'Sala (2)',
#   'L.A. (2)',
#   'United (2)'],
#  ['Singapore (2)',
#   'the Paciﬁc Ocean (2)',
#   'Micronesia (2)',
#   'Kiribati (2)',
#   'Pokfulam (1)',
#   'Hong Kong (1)',
#   'Canberra (1)'],
#  ['Argentina (5)',
#   'England (1)',
#   'London (1)',
#   '3JH (1)',
#   'UK (1)',
#   'Universidad (1)',
#   'Avenida (1)'],
#  ['the Quinto Basin (9)',
#   'Italy (7)',
#   'Cerba (7)',
#   'kPa (6)',
#   'Mediterranean (4)',
#   'the Adriatic Sea (3)',
#   'The Quinto Basin (2)'],
#  ['japonica (21)',
#   'Formosa (9)',
#   'Atalanta (8)',
#   'Brazil (7)',
#   'Oryza (7)',
#   'Lima (4)',
#   'mM (2)'],
#  ['China (8)',
#   'Western Songnen Plain (3)',
#   's.e. (3)',
#   'Chongqing 400715 (2)',
#   'Japan (2)',
#   'Phragmites (1)',
#   'Chongqing 400714 (1)'],
#  ['Moscow (3)',
#   'Mongolia (3)',
#   'Central Asia (2)',
#   'the Gobi Desert  E. I. Pankovaa (1)',
#   'Geography (1)',
#   'Trans(cid:2)Altai (1)',
#   'Western Siberia (1)'],
#  ['Aktau (7)',
#   'the Ili Basin (6)',
#   'Kazakhstan (4)',
#   'Germany (3)',
#   'Earth (3)',
#   'Central  Asia (3)',
#   'Tian (3)'],
#  ['Liangzhu (16)',
#   'China (8)',
#   'Liangzhu City (7)',
#   'Nanjing (4)',
#   'Yangtze (3)',
#   'the Yangtze Delta (3)',
#   'Ca (3)'],
#  ['States (16)',
#   'Spain (9)',
#   'Portugal (8)',
#   'France (5)',
#   'Brussels (3)',
#   'Mediterranean (2)',
#   'Uruguay (2)'],
#  ['Spain (3)',
#   'Canary Islands (3)',
#   'Hesp (3)',
#   'Geomorphological (3)',
#   'El Inglés (2)',
#   'Universidad (1)',
#   'Las \n\n (1)'],
#  ['Senegal (33)',
#   'West Africa (7)',
#   'Saint-Louis (6)',
#   'Sine (5)',
#   'the Senegal River (4)',
#   'France (2)',
#   'Africa (2)'],
#  ['Bosmina (14)',
#   'Alona (13)',
#   'Canada (11)',
#   'Camptocercus (9)',
#   'Mackenzie Delta (8)',
#   'the Mackenzie Delta (8)',
#   'Arctic (7)'],
#  ['New Jersey (12)',
#   'New Jersey’s (3)',
#   'Troy (3)',
#   'Wetland (2)',
#   'New Brunswick (1)',
#   'Ithaca (1)',
#   'Konarska (1)'],
#  ['Sinai (27)',
#   'Israel (15)',
#   'Negev (12)',
#   'Sadek (8)',
#   'Kashai (8)',
#   'Egypt (7)',
#   'the Dead Sea (7)'],
#  ['South Africa (18)',
#   'Africa (7)',
#   'South (5)',
#   'South  Africa (4)',
#   'Sarcocornia (4)',
#   'Turpie (2)',
#   'Estuarine (2)'],
#  ['Italy (5)',
#   'San Vitale (3)',
#   'Adriatic Sea (2)',
#   'Romagna (1)',
#   'Nazarnia (1)',
#   'Northern Italy (1)',
#   'Carminati (1)'],
#  ['Tashkent (5)',
#   'Karakalpakstan (3)',
#   'pp. (3)',
#   'Uzbekistan (2)',
#   'the  Republic (1)',
#   'The  Republic (1)',
#   'Aral Sea (1)'],
#  ['pBCORc115 (6)',
#   'Poly(A (2)',
#   'Belgium (1)',
#   'Departments (1)',
#   'Gainesville (1)',
#   'Ottawa (1)',
#   'Ontario (1)'],
#  ['Netherlands (26)',
#   'Zeeland (8)',
#   'Friesland (5)',
#   'North  Sea (3)',
#   'Holland (3)',
#   'Zuur (2)',
#   'Gelderland (2)']]

# %% [markdown]
# #### Making Pandas DataFrame

# %%
import pandas as pd

# Remove "PDF Papers (20)" from the strings in pdf_files
filename = [file.replace("PDF Papers (20)/", "") for file in filename]

# Extract the columns from list_of_lists
col1 = [item[0] if len(item) > 0 else '' for item in list_of_lists]
col2 = [item[1] if len(item) > 1 else '' for item in list_of_lists]
col3 = [item[2] if len(item) > 2 else '' for item in list_of_lists]
col4 = [item[3] if len(item) > 3 else '' for item in list_of_lists]
col5 = [item[4] if len(item) > 4 else '' for item in list_of_lists]
col6 = [item[5] if len(item) > 5 else '' for item in list_of_lists]
col7 = [item[6] if len(item) > 6 else '' for item in list_of_lists]

# Create the dataframe
data = {
    'PDF File': filename,
    'Col1': col1,
    'Col2': col2,
    'Col3': col3,
    'Col4': col4,
    'Col5': col5,
    'Col6': col6,
    'Col7': col7
}
df = pd.DataFrame(data)

# %%
df
# Out:
#                                               PDF File  \
# 0    /Users/othmaneechchabi/Desktop/Research/Data+/...
# 1    /Users/othmaneechchabi/Desktop/Research/Data+/...
# 2    /Users/othmaneechchabi/Desktop/Research/Data+/...
# 3    /Users/othmaneechchabi/Desktop/Research/Data+/...
# 4    /Users/othmaneechchabi/Desktop/Research/Data+/...
# ..                                                 ...
# 208  /Users/othmaneechchabi/Desktop/Research/Data+/...
# 209  /Users/othmaneechchabi/Desktop/Research/Data+/...
# 210  /Users/othmaneechchabi/Desktop/Research/Data+/...
# 211  /Users/othmaneechchabi/Desktop/Research/Data+/...
# 212  /Users/othmaneechchabi/Desktop/Research/Data+/...
#
#                         Col1                Col2              Col3  \
# 0                 Mogao (12)           Japan (5)         China (3)
# 1                 Africa (3)          London (2)        Brazil (1)
# 2                  River (6)       Australia (5)          I.D. (5)
# 3                   Oman (8)     El-Kaliouby (4)        Muscat (2)
# 4    the Colorado River (13)         Mexico (12)      Colorado (7)
# ..                       ...                 ...               ...
# 208        South Africa (18)          Africa (7)         South (5)
# 209                Italy (5)      San Vitale (3)  Adriatic Sea (2)
# 210             Tashkent (5)  Karakalpakstan (3)           pp. (3)
# 211            pBCORc115 (6)          Poly(A (2)       Belgium (1)
# 212         Netherlands (26)         Zeeland (8)     Friesland (5)
#
#                            Col4               Col5                Col6  \
# 0                     Osaka (2)      Ito Misae (1)        Toyonaka (1)
# 1              South Africa (1)    West Africa (1)          Uganda (1)
# 2                  Eldridge (1)         Talsma (1)           South (1)
# 3             Northern Oman (2)           J.D. (2)           Young (2)
# 4    the Gulf of California (7)           Nile (6)           Egypt (6)
# ..                          ...                ...                 ...
# 208           South  Africa (4)    Sarcocornia (4)          Turpie (2)
# 209                 Romagna (1)       Nazarnia (1)  Northern Italy (1)
# 210              Uzbekistan (2)  the  Republic (1)   The  Republic (1)
# 211             Departments (1)    Gainesville (1)          Ottawa (1)
# 212              North  Sea (3)        Holland (3)            Zuur (2)
#
#                       Col7
# 0        Dunhuang city (1)
# 1                China (1)
# 2    New  South  Wales (1)
# 3                Egypt (1)
# 4                Indus (5)
# ..                     ...
# 208          Estuarine (2)
# 209          Carminati (1)
# 210           Aral Sea (1)
# 211            Ontario (1)
# 212         Gelderland (2)
#
# [213 rows x 8 columns]

# %%
df.to_csv('text_analysis_test.csv')
